# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
auto_df=pd.read_csv("E:/python projects/automobile/automobile.csv")

# %%
auto_df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto_df.tail(5)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
auto_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
auto_df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
auto_df.shape
# Out:
# (205, 26)

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Handling Missing values

# %%
auto_df.replace("?",np.nan,inplace=True)

# %%
auto_df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
auto_df.dropna(subset="price",axis=0,inplace=True)

# %%
auto_df["normalized-losses"].fillna(auto_df["normalized-losses"].astype(float).mean(),inplace=True)

# %%
auto_df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
auto_df.dropna(subset=["num-of-doors","bore","stroke","horsepower","peak-rpm"],inplace=True)

# %%
auto_df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
auto_df.shape
# Out:
# (193, 26)

# %% [markdown]
# Changing the Data Types

# %%
auto_df[["bore","normalized-losses","stroke","horsepower","peak-rpm","price"]]=auto_df[["bore","normalized-losses","stroke","horsepower","peak-rpm","price"]].astype(float)

# %%
auto_df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# Removing Duplicates

# %%
auto_df.drop_duplicates(inplace=True)

# %%
auto_df.shape
# Out:
# (193, 26)

# %% [markdown]
# Outliers

# %%
auto_df=auto_df[(auto_df["price"]>=auto_df["price"].quantile(0.05)) & (auto_df["price"]<=auto_df["price"].quantile(0.95))]

# %%
auto_df.shape
# Out:
# (173, 26)

# %% [markdown]
# EDA

# %% [markdown]
# 1. Distribution of Car Prizes.

# %%
plt.hist(x=auto_df["price"],bins=10,edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution of Car Prices")
plt.show()

# %% [markdown]
# We intrepret from the histogram plot that maximum car price range in 5000-20000.

# %% [markdown]
# 2. Relation of Engine Size and Horsepower.

# %%
sns.scatterplot(x="engine-size",y="horsepower",data=auto_df,hue="fuel-type")
plt.xlabel("Engine size")
plt.ylabel("Horsepower")
plt.title("Engine size vs Horsepower by fuel types")
plt.show()
# Out:
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# From Scatter Plot we intrepret that with an increase in Engine Size There is increase in the horsepower for both Diesel as well as Gas Cars ie: they are directly proportional to each other.

# %% [markdown]
# 3. Relation of Body Style with Price.

# %%
sns.boxplot(x="body-style",y="price",data=auto_df)
plt.xlabel("Body Style")
plt.ylabel("Price")
plt.title("Body Style vs Price")
plt.show()
# Out:
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# 4.  How does the fuel economy (city-mpg and highway-mpg) vary between different body styles?

# %%
mpg=["city-mpg","highway-mpg"]
mpg_mean=auto_df.groupby("body-style")[mpg].mean()

# %%
mpg_mean.plot(kind="bar",rot=0)
plt.xlabel("Body Style")
plt.ylabel("Average MPG")
plt.title("Average City MPG ang Highway MPG versur Body Style")
plt.show()

# %% [markdown]
# Therefore we conclude that Hatchback Body style has highest average MPG both in city as well as on Highway.

# %% [markdown]
# 5. How does fuel economy vary with different makers?

# %%
mpg_mean1=auto_df.groupby("make")[mpg].mean()

# %%
mpg_mean1.plot(kind="bar")
plt.xlabel("Make")
plt.ylabel("Average MPG")
plt.title("Average MPG vaersus the makers of car")
plt.show()

# %% [markdown]
# So we conclude that Chevrolet has highest fuel efficiency both in City as well as on Hoighway.

# %% [markdown]
# 6. How does fuel efficiency vary with different fuel types?

# %%
mpg_mean2=auto_df.groupby("fuel-type")[mpg].mean()

# %%
mpg_mean2.plot(kind="bar",rot=0)
plt.xlabel("Fuel Type")
plt.ylabel("Average MPG")
plt.title("Average MPG versus Fuel Type")
plt.show()

# %% [markdown]
# So we conclude that diesel cars have higher average MPG both in city as well as on highways.

# %% [markdown]
# 7. How does the length, width, height of the car vary with different make and body style?

# %%
dim=["length","width","height"]
body_style_mean=auto_df.groupby("body-style")[dim].mean()
make_mean=auto_df.groupby("make")[dim].mean()

# %%
body_style_mean.plot(kind="bar",rot=0)
plt.title("Body Style versur average dimensions")
plt.xlabel("Body Style")
plt.ylabel("Average dimensions")
# Out:
# Text(0, 0.5, 'Average dimensions')

# %% [markdown]
# So we conclude that Average length is highest in Wagon while the other two dimensions are nearly equal for all styles.

# %%
make_mean.plot(kind="bar")
plt.title("make versus average Dimensions")
plt.xlabel("Make")
plt.ylabel("Average Dimensions")
# Out:
# Text(0, 0.5, 'Average Dimensions')

# %% [markdown]
# So Jaguar makes the longest cars.

# %%
auto_df.groupby("drive-wheels")["price"].mean()
# Out:
# drive-wheels
# 4wd    10241.000000
# fwd     9596.182692
# rwd    17267.868852
# Name: price, dtype: float64

# %% [markdown]
# 8. Fimd the everage Price of cars based on the number of Drive Wheels?

# %%
sns.barplot(x=auto_df.groupby("drive-wheels")["price"].mean().index,y=auto_df.groupby("drive-wheels")["price"].mean().values)
plt.xlabel("Drive Wheels")
plt.ylabel("Average Price")
plt.title("Drive wheels versus Average price")
plt.show()
# Out:
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Junaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# So we conclude that rwd cars have highest average price.

# %% [markdown]
# 9. What is the percentage of each body style?

# %%
style_count=auto_df.groupby("body-style")["body-style"].count()

# %%
plt.pie(style_count.values,labels=style_count.index,autopct="%1.0f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1f3ab21fe50>,
# ...
#  [Text(1.0970993239530333, 0.07983153125048686, 'convertible'),
#   Text(1.0646421521133713, 0.27665337146582764, 'hardtop'),
#   Text(0.2475542709556223, 1.0717821060885606, 'hatchback'),
#   Text(-0.822342027323276, -0.7305844168183745, 'sedan'),
#   Text(0.9971729865545308, -0.4643770395765901, 'wagon')],
#  [Text(0.5984178130652908, 0.043544471591174645, '2%'),
#   Text(0.5807139011527479, 0.15090183898136053, '3%'),
#   Text(0.13502960233943032, 0.5846084215028512, '31%'),
#   Text(-0.44855019672178686, -0.3985005909918406, '49%'),
#   Text(0.5439125381206531, -0.2532965670417764, '14%')])

# %% [markdown]
# So we conclude that the highest percentage is of Sedan body Style and lowest of Convertible
